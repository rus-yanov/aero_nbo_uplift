# %%
import pandas as pd
from src.models.rule_based import RuleBasedConfig, evaluate_rule_based_ctr

df = pd.read_csv("data/processed/nbo_dataset.csv")

cfg = RuleBasedConfig(
    recent_days_threshold=7,
    warm_days_threshold=30,
    high_monetary_threshold=10000.0,
    low_frequency_threshold=1,
)

ctr_baseline = evaluate_rule_based_ctr(df, cfg)
print(f"Rule-based CTR baseline: {ctr_baseline:.4f}")
